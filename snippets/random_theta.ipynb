# %%
import numpy as np

# %%
# create numpy vector of length 514 with random decimals between -10 and 10
init_epsilon = 10
theta = np.random.rand(514) * (2 * init_epsilon) - init_epsilon
theta
# Out:
# array([ 5.60548107e+00,  2.31258411e+00,  4.78053598e+00,  1.83419607e+00,
#         4.31938710e-01, -5.35546318e+00, -6.49254142e+00,  7.65295268e+00,
#        -3.10289191e+00, -3.10325130e-01,  4.95323986e+00, -9.86441878e-01,
#         8.20609479e+00, -1.71425496e+00,  2.01382075e+00, -5.60081904e+00,
#         8.23709288e+00, -2.48804122e+00, -1.76859951e+00, -6.31968656e+00,
#        -3.57095103e+00, -2.41420259e+00, -9.29338479e+00,  7.29930853e+00,
#        -8.76027448e+00, -9.76626495e+00,  8.07074689e-01,  7.21816560e+00,
#         8.94655557e+00, -4.41625754e+00, -9.26319207e+00, -8.78480538e+00,
#        -7.37337841e+00, -8.15697471e+00, -2.85513880e+00,  2.49854453e+00,
#        -8.65040599e+00,  2.68808290e+00,  7.40430058e+00,  2.10455988e-01,
#         4.81730088e+00,  6.27361498e+00, -9.28089353e+00,  1.50010481e+00,
#        -2.16549471e+00, -5.42170072e-01, -2.54155838e+00, -5.80068936e+00,
# ...

# %%
theta.min(), theta.max()
# Out:
# (-9.99953565014685, 9.95544017331698)
